# %%
import pandas as pd
from pymongo import MongoClient

# %%
client = MongoClient("mongodb://igenie_readwrite:igenie@35.189.101.142:27017/dax_gcp")
db = client.dax_gcp
collection = db.tweets

# %%
cursor = collection.find({"nltk_sentiment_score":{"$exists":True}},{"_id":0,"semi_processed_text":1, "nltk_sentiment_score":1,"google_sentiment_score":1})

# %%
results = list(cursor)
df = pd.DataFrame(results)

# %%
pd.options.display.max_colwidth = 140
df
# Out:
#     google_sentiment_score nltk_sentiment_score  \
# 0                 Positive              Neutral
# 1                 Positive             Positive
# 2                 Positive              Neutral
# 3                 Positive             Positive
# 4                 Negative              Neutral
# 5                 Positive             Positive
# 6                  Neutral              Neutral
# 7                 Positive             Positive
# 8                 Negative              Neutral
# 9                  Neutral             Positive
# 10                 Neutral             Positive
# 11                Positive             Positive
# 12                Positive              Neutral
# 13                Positive             Positive
# 14                 Neutral              Neutral
# 15                Positive             Positive
# 16                 Neutral              Neutral
# 17                Positive             Positive
# ...
