# %%
from sklearn.externals import joblib
import pandas as pd
from pymongo import MongoClient
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
client = MongoClient("mongodb://igenie_readwrite:igenie@35.189.101.142:27017/dax_gcp")
db = client["dax_gcp"]
collection = db["tweets"]

# %%
text_clf = joblib.load(r"C:\Users\Uly\Desktop\Desktop\DAX\models\twitter_naive_bayes\model.plk")

# %%
#getting data
cursor = collection.find({"constituent":"BMW"}, {"text":1,"processed_text":1}).limit(1000)
tweets = list(cursor)

# %%
X_test = []
for doc in tweets:
    X_test.append(" ".join(doc["processed_text"]))

# %%
predicted = text_clf.predict(X_test)

# %%
for doc, category in zip(X_test, predicted):
    print('%r => %s' % (doc, category))

# %%
df
# Out:
#                                         processed_text  relevance
# 0                         rt luxbucketlist bmw or benz          0
# 1    bmw until soon rozenkohlschuss the bet ballpoi...          0
# 2    @ quantus32 leas contract bmw torn, new rental...          0
# 3    bmw field 1975 3.0 csl #25 1972 alpina 2002ti ...          0
# 4                         bmw m2 coupé f87 spot warsaw          0
# 5    bmw field 1975 3.0 csl #25 1972 alpina 2002ti ...          0
# 6    bmw field 1975 3.0 csl #25 1972 alpina 2002ti ...          0
# 7    I like the @youtube video: with the bmw m4 on ...          0
# 8    Rt @libertelibero: @ernstvall @sz doe not buy ...          0
# 9    Rt @libertelibero: @ernstvall @sz the crime ha...          0
# 10   onboard classix bmw z4 gt3 rudi adam vln 2.lau...          0
# 11   Rt @nihtgenga: vw, daimler, audi, bmw and pors...          0
# 12   Rt @libertelibero: @ernstvall @sz doe not buy ...          0
# ...
