# %%
from pymongo import MongoClient

# %%
#get MongoDB client
client = MongoClient("mongodb://igenie:igenie@ds019654.mlab.com:19654/dax")

#get dax database
db = client.dax

#get historical collection
collection = db['historical']

#get a single document about Allianz
single_document = collection.find_one({"constituent": "Allianz"})

# %%
single_document
# Out:
# {'_id': ObjectId('596902bbd387bd07c5dd80fd'),
#  'closing_price': 97.5,
#  'constituent': 'Allianz',
#  'daily_high': 98.3,
#  'daily_low': 91.5,
#  'date': datetime.datetime(2003, 1, 2, 0, 0),
#  'opening_price': 92.8,
#  'turnover': 8474467.0,
#  'volume': 90081.0}

# %%
#get historical data for BMW
for item in collection.find({"constituent": "BMW"}):
    print(item)
    print("\n")
# Out:
# {'volume': 27665.0, 'closing_price': 29.8, 'turnover': 811866.0, 'daily_low': 28.6, 'daily_high': 29.9, '_id': ObjectId('5969048bd387bd07c5ddc91d'), 'date': datetime.datetime(2003, 1, 2, 0, 0), 'constituent': 'BMW', 'opening_price': 29.0}
#
#
# {'volume': 27901.0, 'closing_price': 30.1, 'turnover': 843692.0, 'daily_low': 29.8, 'daily_high': 30.8, '_id': ObjectId('5969048bd387bd07c5ddc91c'), 'date': datetime.datetime(2003, 1, 3, 0, 0), 'constituent': 'BMW', 'opening_price': 30.5}
#
#
# {'volume': 25858.0, 'closing_price': 30.5, 'turnover': 774608.0, 'daily_low': 28.9, 'daily_high': 30.8, '_id': ObjectId('5969048bd387bd07c5ddc91b'), 'date': datetime.datetime(2003, 1, 6, 0, 0), 'constituent': 'BMW', 'opening_price': 30.8}
#
#
# {'volume': 42444.0, 'closing_price': 30.1, 'turnover': 1271899.0, 'daily_low': 29.1, 'daily_high': 30.5, '_id': ObjectId('5969048bd387bd07c5ddc91a'), 'date': datetime.datetime(2003, 1, 7, 0, 0), 'constituent': 'BMW', 'opening_price': 30.5}
#
#
# ...
